# %% [markdown]
# #**Experiment No. 6**

# %% [markdown]
# # **1. Describe all three data set in terms of following : how many features, their categories (num,text,categorical, nominal,ordinal etc), number of tuples, missing values.**
#
# #**1.**
# **1.  Iris Dataset**
#
# The Iris dataset is one of the most commonly used datasets for classification problems in data science and machine learning.
#
# 1. Number of Features: 5
# * Sepal Length
# * Sepal Width
# * Petal Length
# * Petal Width
# * Species
#
# 2. Feature Categories:
#
# * Numerical features: Sepal length, sepal width, petal length, petal width (continuous values).
#
# * Categorical feature: Species (Nominal category – Setosa, Versicolor, Virginica).
#
# 3. Number of Tuples (Rows): 150 observations of iris flowers.
#
# 4. Missing Values:
# The dataset does not contain any missing values, making it clean and easy to use for analysis.
#
# **2. Air Quality Dataset**
# The Air Quality dataset contains measurements of air pollutants recorded by chemical sensors.
#
# 1. Number of Features: 15 attributes including sensor readings and environmental measurements.
#
# 2. Feature Categories:
# * Numerical features: CO concentration, NOx levels, benzene concentration, temperature, humidity, etc.
# * Temporal/Text features: Date and time attributes that record when the measurement was taken.
#
# 3. Number of Tuples (Rows): Approximately 9358 observations collected over a period of time.
#
# 4. Missing Values:
# The dataset contains missing values represented by -200, which indicates that the sensor failed to record data at that time.
#
# **3. Wine Quality Dataset**
# The Wine Quality dataset contains chemical properties of wine and a quality score given by experts.
#
# 1. Number of Features: 12 attributes
#
# 11 physicochemical input features
#
# 1 output feature (quality)
#
# 2. Feature Categories:
#
# Numerical features: Fixed acidity, volatile acidity, citric acid, residual sugar, chlorides, sulphates, alcohol, etc.
#
# Ordinal feature: Quality score (ranges from 0–10, representing increasing wine quality).
#
# 3. Number of Tuples (Rows):
# The commonly used red wine dataset contains 1599 samples.
#
# 4. Missing Values:
# The dataset generally does not contain missing values, so it is suitable for statistical analysis and machine learning tasks.

# %% [markdown]
# #**2. In IRIS data set which non graphical EDA is performed ?**
# #**2.**
# **In the Iris Dataset, non-graphical Exploratory Data Analysis (EDA) is used to understand the dataset without visual graphs.**
#
# The following methods are performed:
#
# **1. Dataset Structure Analysis :**
# * shape() is used to determine the number of rows and columns.
# * info() is used to view data types and memory usage.
#
# **2. Summary Statistics :**
# * describe() function provides statistical summary including mean, standard * deviation, minimum, maximum, and quartiles.
#
# **3. Central Tendency Measures :**
# * Mean
# * Median
#
# **4. Dispersion Measures :**
# * Standard deviation
# * Variance
# * Range
#
# **5. Frequency Distribution:**
#
# value_counts() is used to count the number of samples in each species category.
#
# These techniques help understand data distribution, central tendency, and variability without visualization.
#
# **Example using Python:

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from google.colab import drive

drive.mount('/content/drive')

# After mounting, ensure the path to your CSV file is correct.
# You might need to adjust the path if the file is located elsewhere in your Drive.
data = pd.read_csv('/content/drive/MyDrive/MY_COLLAB_NOTEBOOK/Iris.csv')

sns.pairplot(data)
plt.show()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from google.colab import drive

drive.mount('/content/drive')

# After mounting, ensure the path to your CSV file is correct.
# You might need to adjust the path if the file is located elsewhere in your Drive.
data = pd.read_csv('/content/drive/MyDrive/MY_COLLAB_NOTEBOOK/Iris.csv')

# Drop the non-numeric 'Species' column before calculating correlation
numeric_data = data.drop('Species', axis=1)
sns.heatmap(numeric_data.corr(),cmap="YlGnBu", linecolor='white', linewidths=1)
plt.show()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # **3. In  Air Quality data set which graph is used to perform multivariate analysis?**
# #**3.**
# In the Air Quality Dataset, multivariate analysis means analyzing more than two variables at the same time to understand relationships among them.
#
# A commonly used graph for multivariate analysis is the Pair Plot.
#
# 1. Explanation:
#
# * A Pair Plot displays relationships between multiple variables simultaneously.
#
# * It shows scatter plots for each pair of variables and distribution on the diagonal.
#
# * It helps identify correlations, clusters, and patterns among variables such as CO, NO₂, Temperature, and Humidity.
#
# Example using Python:

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from google.colab import drive

drive.mount('/content/drive')

# After mounting, ensure the path to your CSV file is correct.
# You might need to adjust the path if the file is located elsewhere in your Drive.
data = pd.read_csv('/content/drive/MyDrive/MY_COLLAB_NOTEBOOK/AirQuality.csv')

sns.pairplot(data)
plt.show()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # **4. In Wine quality data set, can you do non graphical EDA ? Explain your answer.**
# #**4.**
# Yes, we can perform non-graphical EDA on the Wine Quality dataset. Non-graphical EDA means analyzing the data using statistical and numerical summaries instead of charts or plots.
#
# In this dataset, we can use methods like **info()** and **shape** to understand the structure of the data, **describe()** to get statistical measures such as mean, minimum, maximum, and standard deviation, and **isnull()** to check for missing values. We can also use **corr()** to see the correlation between different features like alcohol, acidity, and quality.
#
# So, even without using graphs, we can still understand the distribution, relationships, and overall characteristics of the dataset using these numerical techniques.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from google.colab import drive

drive.mount('/content/drive')

# After mounting, ensure the path to your CSV file is correct.
# You might need to adjust the path if the file is located elsewhere in your Drive.
data = pd.read_csv('/content/drive/MyDrive/MY_COLLAB_NOTEBOOK/winequality-white.csv')

# Calculate the distribution of wine quality levels
quality_counts = df['quality'].value_counts().sort_index()

# Create a pie chart
plt.figure(figsize=(8, 8))
plt.pie(quality_counts, labels=quality_counts.index, autopct='%1.1f%%', startangle=140, colors=plt.cm.Paired.colors)
plt.title('Distribution of Wine Quality Levels')
plt.axis('equal') # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
